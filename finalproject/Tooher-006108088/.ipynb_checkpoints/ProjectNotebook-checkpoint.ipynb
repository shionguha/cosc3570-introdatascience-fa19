# %% [markdown]
# This notebook contains the Data Science Project by Katie Tooher an inquiry into US Education data by state. This data set was sourced from Kaggle https://www.kaggle.com/noriuk/us-education-datasets-unification-project#states_all_extended.csv
#
# For the purposes of this project we will be using the "states_all_extended.csv" because it contains all the numbers for each state's education statistics but includes enrollment data for race and gender.
#
# Data Ranges from 1992 to 2017
#
# The primary KPI's that I will be using for this project include:
#
# 1. GRADES_ALL: The count of all students in the state.
#
# 2. The represented races which include AM (American Indian or Alaska Native), AS (Asian), HI (Hispanic/Latino), BL (Black or African American), WH (White), HP (Hawaiian Native/Pacific Islander), and TR (Two or More Races).
#
# 3. The represented genders include M (Male) and F (Female)
# In addition to the demographic data I will also be looking at the Revenue columns including:
#
# - Total_Revenue
# - Federal_Revenue
# - State_Revenue
# - Local_Revenue
# - Total Expenditure (state)
# - Instruction Expenditure
# I will also lightly look into the average test scores section, however that portion seems to be a tad sparce in comparison to the amounts of other data that are provided.

# %%
import pandas as pd                   #alias --> pd
import datetime                       #getting current realtime
from os import listdir
from os.path import isfile, join
import glob                           #a library to specify using unix / paths
import re

# %%
##reading entire csv
df = pd.read_csv("states_all_extended_copy.csv")
df
# Out:
#           STATE  YEAR    ENROLL  TOTAL_REVENUE  FEDERAL_REVENUE  \
# 0       ALABAMA  1992       NaN      2678885.0         304177.0
# 1       ALABAMA  1993  727716.0      2827391.0         331409.0
# 2       ALABAMA  1994  730004.0      2970223.0         331823.0
# 3       ALABAMA  1995  727480.0      3367437.0         328957.0
# 4       ALABAMA  1996  735912.0      3365113.0         334858.0
# 5       ALABAMA  1997  737386.0      3981788.0         376200.0
# 6       ALABAMA  1998  739321.0      4140537.0         374153.0
# 7       ALABAMA  1999  737639.0      4471546.0         393095.0
# 8       ALABAMA  2000  730184.0      4885917.0         425978.0
# 9       ALABAMA  2001  728532.0      4832946.0         466150.0
# 10      ALABAMA  2002  726367.0      5128559.0         508425.0
# 11      ALABAMA  2003  727900.0      5196054.0         567704.0
# 12      ALABAMA  2004  730418.0      5356113.0         625666.0
# 13      ALABAMA  2005  729342.0      5889966.0         665924.0
# ...

# %% [markdown]
# At first inspection of this dataset, it already follows the basic principles of tidy data in the sense that each row shows an entire instance of one year for a state with each of its other kpi's like revenue, expenditure, etc.
#
# The basic things that needed to be cleaned were certain sections that were missing data -- most 2017 rows were missing the data because that must have been the latest the data was inputed.
# Sections like NORTHERN_MARIANAS and NORTHERN_MARIANA_ISLANDS had different names, but were the same territory after further inspection that had changed their legal name, or were perhaps inputed incorretly.
#
# The following sections did not make sense to leave into the dataset:
#     DOD_-_FOREIGN
#     DOD_-_DOMESTIC
#     DOD_-_OVERSEAS
#     DOD_(OVERSEAS_AND_DOMESTIC_COMBINED)
#     DOD_DOMESTIC

# %%
import os
import folium
import pandas as pd
import geopandas

# %%
us_states = os.path.join('us_states.json')

# %%
m = folium.Map([43, -100], zoom_start=4)

folium.GeoJson(us_states).add_to(m)

m.save(os.path.join('enrollment.html'))

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import geopandas

gdf = geopandas.read_file(us_states)

m = folium.Map([43, -100], zoom_start=4)

folium.GeoJson(
    gdf,
).add_to(m)

m.save(os.path.join('enrollment.html'))

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m = folium.Map([43, -100], zoom_start=4)

folium.GeoJson(
    us_states,
    style_function=lambda feature: {
        'fillColor': '#ffff00',
        'color': 'black',
        'weight': 2,
        'dashArray': '5, 5'
    }
).add_to(m)

m.save(os.path.join('enrollment.html'))

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m = folium.Map([43, -100], zoom_start=4)

folium.GeoJson(
    us_states,
    style_function=lambda feature: {
        'fillColor': 'green' if 'e' in feature['properties']['name'].lower() else '#ffff00',
        'color': 'black',
        'weight': 2,
        'dashArray': '5, 5'
    }
).add_to(m)

m.save(os.path.join('enrollment.html'))

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#load data
state_education = os.path.join("States_Averages.csv")
state_data = pd.read_csv(state_education)
state_data.head(10)
# Out:
#    id        State  Average  Unnamed: 3
# 0  AL      ALABAMA   684875         NaN
# 1  AK       ALASKA   121258         NaN
# 2  AZ      ARIZONA   878632         NaN
# 3  AR     ARKANSAS   428071         NaN
# 4  CA   CALIFORNIA  5562741         NaN
# 5  CO     COLORADO   704613         NaN
# 6  CT  CONNECTICUT   506519         NaN
# 7  DE     DELAWARE   110613         NaN
# 8  FL      FLORIDA  2304123         NaN
# 9  GA      GEORGIA  1402157         NaN

# %%
state_data.drop(['Unnamed: 3'], axis=1)
# Out:
#     id           State  Average
# 0   AL         ALABAMA   684875
# 1   AK          ALASKA   121258
# 2   AZ         ARIZONA   878632
# 3   AR        ARKANSAS   428071
# 4   CA      CALIFORNIA  5562741
# 5   CO        COLORADO   704613
# 6   CT     CONNECTICUT   506519
# 7   DE        DELAWARE   110613
# 8   FL         FLORIDA  2304123
# 9   GA         GEORGIA  1402157
# 10  HI          HAWAII   167718
# 11  ID           IDAHO   241035
# 12  IL        ILLINOIS  1879196
# 13  IN         INDIANA   936377
# 14  IA            IOWA   450928
# 15  KS          KANSAS   431393
# 16  KY        KENTUCKY   614601
# 17  LA       LOUISIANA   668271
# 18  ME           MAINE   184524
# 19  MD        MARYLAND   776885
# 20  MA   MASSACHUSETTS   877276
# 21  MI        MICHIGAN  1495108
# 22  MN       MINNESOTA   779597
# 23  MS     MISSISSIPPI   445383
# 24  MO        MISSOURI   835881
# 25  MT         MONTANA   139756
# 26  NE        NEBRASKA   270865
# 27  NV          NEVADA   340757
# ...

# %%
#a function that maps one value to a RGB color (of the form #RRGGBB)
from branca.colormap import linear

colormap = linear.YlGn_09.scale(
    state_data.Average.min(),
    state_data.Average.max())

print(colormap(5.0))

colormap
# Out:
# #ffffe5
# ...

# %%
education_dict = state_data.set_index('id')['Average']
education_dict['AL']
education_dict['CA']
#print(education_dict)
# Out:
# 5562741

# %%
#now choropleth
color_dict = {key: colormap(education_dict[key]) for key in education_dict.keys()}
print(color_dict)
# Out:
# {'AL': '#f8fdbf', 'AK': '#ffffe3', 'AZ': '#f3fbb6', 'AR': '#fbfecf', 'CA': '#004529', 'CO': '#f8fdbd', 'CT': '#fbfeca', 'DE': '#ffffe4', 'FL': '#a0d889', 'GA': '#dcf1a5', 'HI': '#feffe0', 'ID': '#feffdb', 'IL': '#bee596', 'IN': '#f0fab4', 'IA': '#fbfece', 'KS': '#fbfecf', 'KY': '#f9fdc3', 'LA': '#f9fdc0', 'ME': '#feffdf', 'MD': '#f7fcb9', 'MA': '#f3fbb6', 'MI': '#d7efa2', 'MN': '#f7fcb9', 'MS': '#fbfece', 'MO': '#f4fbb7', 'MT': '#ffffe2', 'NE': '#fdffd9', 'NV': '#fcfed5', 'NH': '#feffdf', 'NJ': '#e6f6ad', 'NM': '#fdffd7', 'NY': '#92d283', 'NC': '#e2f4aa', 'ND': '#ffffe4', 'OH': '#ccea9d', 'OK': '#fafdc5', 'OR': '#fafeca', 'PA': '#cceb9d', 'PR': '#fbfecb', 'RI': '#ffffe2', 'SC': '#f9fdc1', 'SD': '#ffffe3', 'TN': '#f4fbb6', 'TX': '#288b47', 'UT': '#fbfecc', 'VT': '#ffffe5', 'VA': '#edf8b2', 'WA': '#f0f9b4', 'WV': '#fdffd9', 'WI': '#f6fcb8', 'WY': '#ffffe5'}

# %%
m = folium.Map([43, -100], zoom_start=4)

folium.GeoJson(
    us_states,
    style_function=lambda feature: {
        'fillColor': color_dict[feature['id']],
        'color': 'black',
        'weight': 1,
        'dashArray': '5, 5',
        'fillOpacity': 0.9,
    }
).add_to(m)

m.save(os.path.join('enrollment.html'))

# %%
colormap.caption = 'Education Enrollment Color Scale'
colormap.add_to(m)

m.save(os.path.join('enrollment.html'))

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#load data
import os
import pandas as pd
expense = os.path.join("average_expenditure.csv")
expense = pd.read_csv(expense)
expense.head(10)
# Out:
#    id                 State  Average_Expenditure
# 0  AL          SOUTH_DAKOTA          1014543.960
# 1  AK          NORTH_DAKOTA          1024572.360
# 2  AZ  DISTRICT_OF_COLUMBIA          1026763.964
# 3  AR               WYOMING          1152672.480
# 4  CA               MONTANA          1298440.720
# 5  CO              DELAWARE          1374873.480
# 6  CT               VERMONT          1444050.600
# 7  DE                 IDAHO          1644000.320
# 8  FL          RHODE_ISLAND          1697362.200
# 9  GA                HAWAII          1775751.760

# %%
#a function that maps one value to a RGB color (of the form #RRGGBB)
from branca.colormap import linear

colormap = linear.PuRd_09.scale(
    expense.Average_Expenditure.min(),
    expense.Average_Expenditure.max())

print(colormap(5.0))

colormap
# Out:
# #f7f4f9
# ...

# %%
education_dict = expense.set_index('id')['Average_Expenditure']
education_dict['AL']
education_dict['CA']
# Out:
# 1298440.72

# %%
#now choropleth
color_dict = {key: colormap(education_dict[key]) for key in education_dict.keys()}
print(color_dict)
# Out:
# {'AL': '#f7f4f9', 'AK': '#f7f4f9', 'AZ': '#f7f4f9', 'AR': '#f7f4f9', 'CA': '#f7f4f9', 'CO': '#f7f3f9', 'CT': '#f6f3f9', 'DE': '#f6f3f9', 'FL': '#f6f3f8', 'GA': '#f6f2f8', 'HI': '#f6f2f8', 'ID': '#f5f1f8', 'IL': '#f5f1f8', 'IN': '#f4f0f7', 'IA': '#f3f0f7', 'KS': '#f3eff7', 'KY': '#f3eff6', 'LA': '#f2eef6', 'ME': '#f2eef6', 'MD': '#f1edf6', 'MA': '#f0ecf5', 'MI': '#efebf4', 'MN': '#efeaf4', 'MS': '#eee9f3', 'MO': '#ede8f3', 'MT': '#ede8f3', 'NE': '#ece7f2', 'NV': '#ece6f2', 'NH': '#ebe5f1', 'NJ': '#eae5f1', 'NM': '#eae5f1', 'NY': '#e9e3f0', 'NC': '#e8e2f0', 'ND': '#e5dced', 'OH': '#e4dbec', 'OK': '#e3d9eb', 'OR': '#e3d8eb', 'PA': '#e3d8ea', 'PR': '#e0d2e8', 'RI': '#ddcbe4', 'SC': '#ddcbe4', 'SD': '#d8c2df', 'TN': '#d1add4', 'TX': '#d0a9d2', 'UT': '#cc9dcc', 'VT': '#ca96c8', 'VA': '#ca96c8', 'WA': '#ca93c7', 'WV': '#dd1f75', 'WI': '#c00d51', 'WY': '#67001f'}

# %%
import folium
n = folium.Map([43, -100], zoom_start=4)

folium.GeoJson(
    us_states,
    style_function=lambda feature: {
        'fillColor': color_dict[feature['id']],
        'color': 'black',
        'weight': 1,
        'dashArray': '5, 5',
        'fillOpacity': 0.9,
    }
).add_to(n)

n.save(os.path.join('expensesmap.html'))
n
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
colormap.caption = 'Average Education Expenditure by State'
colormap.add_to(n)

n.save(os.path.join('expensesmap.html'))

n
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#create column data source from data frame
import pandas
from bokeh.plotting import figure,output_file,show,ColumnDataSource,save
dfe = pandas.read_csv("average_expenditure.csv")
source = ColumnDataSource(dfe)
from bokeh.models.tools import HoverTool

#add color pallet based on chosen factor
from bokeh.transform import factor_cmap
from bokeh.palettes import Blues8

output_file('barchart.html')
state_list = source.data['State'].tolist()
aves_list = source.data['Average_Expenditure'].tolist()
p = figure(y_range=state_list,
           title = 'Average Education Expenditure per State',
           plot_height=600,
           plot_width=600,
           x_axis_label = 'Average Spending per State on Education (mil) 1992-2015',
           y_axis_label = "State",
        tools ="pan,box_select,zoom_in,zoom_out,save"
          )

#glyph line chart
p.hbar(y = 'State',
       right='Average_Expenditure',
       left=9000,
       height=0.4,
       color = "purple",
       fill_alpha=10,
       source = source
       #legend = 'State'
      )

##add legend
# p.legend.orientation='vertical'
# p.legend.location='top_right'
# p.legend.label_text_font_size='10px'

##add tooltips
hover = HoverTool()
hover.tooltips = """
    <div>
        <h3>@State</h3>
        <div><strong> Average: </strong> @Average_Expenditure</div>
    </div>
"""
p.add_tools(hover)

save(p)
# Out:
# '/Users/katietooher/DataScience/ProjectTooher/barchart.html'

# %%
##scatter plot 1 Albama

dfstate2 = pandas.read_csv("alabama.csv")


##USE FOR SECOND SMALLER CHART
from bokeh.plotting import figure,output_file,show,ColumnDataSource,save
source = ColumnDataSource(dfstate2)


output_file('scatterAla.html')
p = figure(plot_width = 600,plot_height= 600,
           title = 'Total State Expenditure for Alabama Education',
           x_axis_label = 'Years 1992-2016',
            y_axis_label = "Spendings on Education")

year_list = source.data['YEAR'].tolist()
expenditure = source.data['TOTAL_EXPENDITURE'].tolist()

p.circle(x = year_list,
        y = expenditure,
        size = 10,
        color = 'navy')


save(p)
# Out:
# '/Users/katietooher/DataScience/ProjectTooher/scatterAla.html'

# %%
##scatter plot 2 california 
dfstate3 = pandas.read_csv("california.csv")
source2 = ColumnDataSource(dfstate3)
year_list = source2.data['Year'].tolist()
expenditure = source2.data['TOTAL_EXPENDITURE'].tolist()

output_file('scatterCal.html')
p = figure(plot_width = 600,plot_height= 600,
           title = 'Total State Expenditure for California Education',
           x_axis_label = 'Years 1992-2016',
            y_axis_label = "Spendings on Education")


p.circle(x = year_list,
        y = expenditure,
        size = 10,
        color = 'green')
save(p)
# Out:
# '/Users/katietooher/DataScience/ProjectTooher/scatterCal.html'

# %% [markdown]
# Now for more cleaning of extrenouous data, I made the decision to remove the rows that contained these "STATE" values mainly because I don't understand why department of defense counts as a United States "State" education category.
# These are the categories that I will remove:
#     DOD_DOMESTIC
#     DOD_OVERSEAS
#     DOD_-_FOREIGN
#     DEPARTMENT_OF_DEFENSE_EDUCATION_ACTIVITY
#     DEPARTMENT_OF_DEFENSE
#     DOD
#     DOD_(OVERSEAS_AND_DOMESTIC_COMBINED)
#
# In addition I am going to remove (but place in a different excell sheet) the data for the following US territories because the amount of data that they have is far less than that of the other states.
#
#
#
#
# Rows to fix -- IE these values were either entered incorrectly or had name changes at some point during the collection of this data:
#     AS 1998 -- American Samoa

# %%
df2 = pd.read_csv("states_all_extended_cleaned.csv",index_col=[0])

##delete all the rows for the ENROLL column that contain the NaN values
df2 = df2.dropna(subset=['ENROLL'])

##now to remove the pesky rows that don't make sense for this dataset
df2 = df2[df2.STATE != 'DOD_DOMESTIC']
df2 = df2[df2.STATE != 'DOD_OVERSEAS']
df2 = df2[df2.STATE != 'DOD_-_FOREIGN']
df2 = df2[df2.STATE != 'DEPARTMENT_OF_DEFENSE_EDUCATION_ACTIVITY']
df2 = df2[df2.STATE != 'DEPARTMENT_OF_DEFENSE']
df2 = df2[df2.STATE != 'DOD']
df2 = df2[df2.STATE != 'DOD_(OVERSEAS_AND_DOMESTIC_COMBINED)']
df2
# Out:
#                     PRIMARY_KEY                 STATE  YEAR   ENROLL  \
# 0                  1993_ALABAMA               ALABAMA  1993   727716
# 1                   1993_ALASKA                ALASKA  1993   121156
# 2                  1993_ARIZONA               ARIZONA  1993   676297
# 3                 1993_ARKANSAS              ARKANSAS  1993   311432
# 4               1993_CALIFORNIA            CALIFORNIA  1993  5129788
# 5                 1993_COLORADO              COLORADO  1993   539538
# 6              1993_CONNECTICUT           CONNECTICUT  1993   471918
# 7                 1993_DELAWARE              DELAWARE  1993   104355
# 8     1993_DISTRICT_OF_COLUMBIA  DISTRICT_OF_COLUMBIA  1993    80937
# 9                  1993_FLORIDA               FLORIDA  1993  1980569
# 10                 1993_GEORGIA               GEORGIA  1993   893557
# 11                  1993_HAWAII                HAWAII  1993   177448
# 12                   1993_IDAHO                 IDAHO  1993   231632
# ...

# %%
##saves the excell sheet with the cleaned data 
df2 = df2.to_csv('states_all_extended_cleaned.csv', encoding='utf-8')

# %% [markdown]
# Topics of Research:
# 1. How do each states compulsory education laws affect the enrollment and or spending on education?
#
# 2. How are test scores for states related to the educational spending per state and why might this be?
#
# 3. How might spending on education be related to gender or ethnicity
#
# Now to Linear and Logistic Regression Models
#
# Linear Regression Assumptions:
# 1. The values used are numeric and not categorical
# 2. Data is free of missing values
# 3. There is a linear relationship between predictors and predicants
# 4. All predictors are independent of one another
# 5. Residuals are normally distributed (perhaps in a perfect world)

# %%
## This perhaps falls into the category of resource consumption forecasting 
import numpy as np
import pandas as pd
from pylab import rcParams
import seaborn as sb
import matplotlib.pyplot as plt

import sklearn
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import scale

from collections import Counter
df2 = pd.read_csv("states_all_extended_cleaned.csv")

# %%
# %matplotlib inline
rcParams['figure.figsize'] = 5,4 
sb.set_style('whitegrid')

# %%
#first linear regression will look at these 3 kpis 
df3 = df2[['STATE', 'YEAR','TOTAL_REVENUE']].copy()
df3
# Out:
#                      STATE  YEAR  TOTAL_REVENUE
# 0                  ALABAMA  1993        2827391
# 1                   ALASKA  1993        1191398
# 2                  ARIZONA  1993        3427976
# 3                 ARKANSAS  1993        1346909
# 4               CALIFORNIA  1993       28043338
# 5                 COLORADO  1993        3058326
# 6              CONNECTICUT  1993        4064158
# 7                 DELAWARE  1993         683954
# 8     DISTRICT_OF_COLUMBIA  1993         721151
# 9                  FLORIDA  1993       11370156
# 10                 GEORGIA  1993        4716559
# 11                  HAWAII  1993        1062475
# 12                   IDAHO  1993         890835
# 13                ILLINOIS  1993       10584624
# 14                 INDIANA  1993        5833420
# 15                    IOWA  1993        2880731
# 16                  KANSAS  1993        2386945
# 17                KENTUCKY  1993        2381148
# 18               LOUISIANA  1993        3438321
# ...

# %%
sb.pairplot(df3)

# %%
print(df3.corr())
# Out:
#                    YEAR  TOTAL_REVENUE
# YEAR           1.000000       0.224483
# TOTAL_REVENUE  0.224483       1.000000

# %%
# df3 = (dtype={'YEAR': int})

# %%
# df3_data = df3.loc[:,(1,2)].values
# df3_target = df.loc[:,1].values

# df3_names = ['YEAR','TOTAL_REVENUE']
# X, y = scale(df3_data), df3_target

##https://www.youtube.com/watch?v=erfZsVZbGJI

# %% [markdown]
# I'm going to try logistic regression here.
#     calcuate the odds ratio to go with it
#
#     Find the probability perhaps of some outcome
#     Perhaps look at data associations
#     Visualize the outcomes of the logistic regression
#
# Use sideways error bars to help model odds ratios for different categories of data

# %%
import pandas as pd
import statsmodels.api as sm
import numpy as np
# %matplotlib inline
import seaborn as sns
sns.set(color_codes=True)
import matplotlib.pyplot as plt

# %%
##grab the selections for modeling, I will be using only two degrees of freedom (adding state but thats just categorical)
#AM - Native American or American Indian
#Do BL GRADES_12_BL next -- African American 
df4 = df2[['STATE','TOTAL_EXPENDITURE','GRADES_12_AM']].copy()
# df4['GRADES_12_AM'] = df4['GRADES_12_AM'].fillna(0)      ##filled na values with 0'
df4 = df4.dropna(subset=['GRADES_12_AM'])        ##deleted the nan because all the 0's would ruin the regression
df4
# Out:
#                      STATE  TOTAL_EXPENDITURE  GRADES_12_AM
# 0                  ALABAMA            2833433         420.0
# 1                   ALASKA            1126398        1394.0
# 2                  ARIZONA            3623946        2422.0
# 3                 ARKANSAS            1376067         124.0
# 4               CALIFORNIA           28110986        2429.0
# 5                 COLORADO            3028305         275.0
# 6              CONNECTICUT            4079943          96.0
# 7                 DELAWARE             694534          22.0
# 8     DISTRICT_OF_COLUMBIA             719440           0.0
# 9                  FLORIDA           11425183         177.0
# 10                 GEORGIA            4647974         108.0
# 11                  HAWAII            1063090          25.0
# 13                ILLINOIS           10744695         154.0
# 14                 INDIANA            5668599         117.0
# 15                    IOWA            2889377          88.0
# ...

# %%
alabama_expense = df4.loc[df4['STATE'] == 'ALABAMA','TOTAL_EXPENDITURE']
alabama_ampop = df4.loc[df4['STATE'] == 'ALABAMA','GRADES_12_AM']
alabama_means = alabama_expense.mean()
alabama_ampop_means = alabama_ampop.mean()


alaska_expense = df4.loc[df4['STATE'] == 'ALASKA','TOTAL_EXPENDITURE']
alaska_ampop = df4.loc[df4['STATE'] == 'ALASKA','GRADES_12_AM']
alaska_means = alaska_expense.mean()
alaska_ampop_means = alaska_ampop.mean()


arizona_expense = df4.loc[df4['STATE'] == 'ARIZONA','TOTAL_EXPENDITURE']
arizona_ampop = df4.loc[df4['STATE'] == 'ARIZONA','GRADES_12_AM']
arizona_means = arizona_expense.mean()
arizona_ampop_means = arizona_ampop.mean()

arkansas_expense = df4.loc[df4['STATE'] == 'ARKANSAS','TOTAL_EXPENDITURE']
arkansas_ampop = df4.loc[df4['STATE'] == 'ARKANSAS','GRADES_12_AM']
arkansas_means = arkansas_expense.mean()
arkansas_ampop_means = arkansas_ampop.mean()

california_expense = df4.loc[df4['STATE'] == 'CALIFORNIA','TOTAL_EXPENDITURE']
california_ampop = df4.loc[df4['STATE'] == 'CALIFORNIA','GRADES_12_AM']
california_means = california_expense.mean()
california_ampop_means = california_ampop.mean()

colorado_expense = df4.loc[df4['STATE'] == 'COLORADO','TOTAL_EXPENDITURE']
colorado_ampop = df4.loc[df4['STATE'] == 'COLORADO','GRADES_12_AM']
colorado_means = colorado_expense.mean()
colorado_ampop_means = colorado_ampop.mean()

connecticut_expense = df4.loc[df4['STATE'] == 'CONNECTICUT','TOTAL_EXPENDITURE']
connecticut_ampop = df4.loc[df4['STATE'] == 'CONNECTICUT','GRADES_12_AM']
connecticut_means = connecticut_expense.mean()
connecticut_ampop_means = connecticut_ampop.mean()

delaware_expense = df4.loc[df4['STATE'] == 'DELAWARE','TOTAL_EXPENDITURE']
delaware_ampop = df4.loc[df4['STATE'] == 'DELAWARE','GRADES_12_AM']
delaware_means = delaware_expense.mean()
delaware_ampop_means = delaware_ampop.mean()

dcolumbia_expense = df4.loc[df4['STATE'] == 'DISTRICT_OF_COLUMBIA','TOTAL_EXPENDITURE']
dcolumbia_ampop = df4.loc[df4['STATE'] == 'DISTRICT_OF_COLUMBIA','GRADES_12_AM']
dcolumbia_means = dcolumbia_expense.mean()
dcolumbia_ampop_means = dcolumbia_ampop.mean()

florida_expense = df4.loc[df4['STATE'] == 'FLORIDA','TOTAL_EXPENDITURE']
florida_ampop = df4.loc[df4['STATE'] == 'FLORIDA','GRADES_12_AM']
florida_means = florida_expense.mean()
florida_ampop_means = florida_ampop.mean()

georgia_expense = df4.loc[df4['STATE'] == 'GEORGIA','TOTAL_EXPENDITURE']
georgia_ampop = df4.loc[df4['STATE'] == 'GEORGIA','GRADES_12_AM']
georgia_means = georgia_expense.mean()
georgia_ampop_means = georgia_ampop.mean()

hawaii_expense = df4.loc[df4['STATE'] == 'HAWAII','TOTAL_EXPENDITURE']
hawaii_ampop = df4.loc[df4['STATE'] == 'HAWAII','GRADES_12_AM']
hawaii_means = hawaii_expense.mean()
hawaii_ampop_means = hawaii_ampop.mean()

illinois_expense = df4.loc[df4['STATE'] == 'ILLINOIS','TOTAL_EXPENDITURE']
illinois_ampop = df4.loc[df4['STATE'] == 'ILLINOIS','GRADES_12_AM']
illinois_means = illinois_expense.mean()
illinois_ampop_means = illinois_ampop.mean()

indiana_expense = df4.loc[df4['STATE'] == 'INDIANA','TOTAL_EXPENDITURE']
indiana_ampop = df4.loc[df4['STATE'] == 'INDIANA','GRADES_12_AM']
indiana_means = indiana_expense.mean()
indiana_ampop_means = indiana_ampop.mean()

iowa_expense = df4.loc[df4['STATE'] == 'IOWA','TOTAL_EXPENDITURE']
iowa_ampop = df4.loc[df4['STATE'] == 'IOWA','GRADES_12_AM']
iowa_means = iowa_expense.mean()
iowa_ampop_means = iowa_ampop.mean()

kansas_expense = df4.loc[df4['STATE'] == 'KANSAS','TOTAL_EXPENDITURE']
kansas_ampop = df4.loc[df4['STATE'] == 'KANSAS','GRADES_12_AM']
kansas_means = kansas_expense.mean()
kansas_ampop_means = kansas_ampop.mean()

louisana_expense = df4.loc[df4['STATE'] == 'LOUISIANA','TOTAL_EXPENDITURE']
louisana_ampop = df4.loc[df4['STATE'] == 'LOUISIANA','GRADES_12_AM']
louisana_means = louisana_expense.mean()
louisana_ampop_means = louisana_ampop.mean()

maryland_expense = df4.loc[df4['STATE'] == 'MARYLAND','TOTAL_EXPENDITURE']
maryland_ampop = df4.loc[df4['STATE'] == 'MARYLAND','GRADES_12_AM']
maryland_means = maryland_expense.mean()
maryland_ampop_means = maryland_ampop.mean()

massachusetts_expense = df4.loc[df4['STATE'] == 'MASSACHUSETTS','TOTAL_EXPENDITURE']
massachusetts_ampop = df4.loc[df4['STATE'] == 'MASSACHUSETTS','GRADES_12_AM']
massachusetts_means = massachusetts_expense.mean()
massachusetts_ampop_means = massachusetts_ampop.mean()

michigan_expense = df4.loc[df4['STATE'] == 'MICHIGAN','TOTAL_EXPENDITURE']
michigan_ampop = df4.loc[df4['STATE'] == 'MICHIGAN','GRADES_12_AM']
michigan_means = michigan_expense.mean()
michigan_ampop_means = michigan_ampop.mean()

minne_expense = df4.loc[df4['STATE'] == 'MINNESOTA','TOTAL_EXPENDITURE']
minne_ampop = df4.loc[df4['STATE'] == 'MINNESOTA','GRADES_12_AM']
minne_means = minne_expense.mean()
minne_ampop_means = minne_ampop.mean()
                        
miss_expense = df4.loc[df4['STATE'] == 'MISSISSIPPI','TOTAL_EXPENDITURE']
miss_ampop = df4.loc[df4['STATE'] == 'MISSISSIPPI','GRADES_12_AM']
miss_means = miss_expense.mean()
miss_ampop_means = miss_ampop.mean()
                       
missouri_expense = df4.loc[df4['STATE'] == 'MISSOURI','TOTAL_EXPENDITURE']
missouri_ampop = df4.loc[df4['STATE'] == 'MISSOURI','GRADES_12_AM']
missouri_means = missouri_expense.mean()
missouri_ampop_means = missouri_ampop.mean()

##Montanna 
mont_expense = df4.loc[df4['STATE'] == 'MONTANA','TOTAL_EXPENDITURE']
mont_means = mont_expense.mean()
mont_ampop = df4.loc[df4['STATE'] == 'MONTANA','GRADES_12_AM']
mont_ampop_means = mont_ampop.mean()
#print("Mean MONTANA spent: ",mont_means,"|| Mean 12th grader native american enrollment: ",mont_ampop_means)

nebraska_expense = df4.loc[df4['STATE'] == 'NEBRASKA','TOTAL_EXPENDITURE']
nebraska_ampop = df4.loc[df4['STATE'] == 'NEBRASKA','GRADES_12_AM']
nebraska_means = nebraska_expense.mean()
nebraska_ampop_means = nebraska_ampop.mean()
                           
nevada_expense = df4.loc[df4['STATE'] == 'NEVADA','TOTAL_EXPENDITURE']
nevada_ampop = df4.loc[df4['STATE'] == 'NEVADA','GRADES_12_AM']
nevada_means = nevada_expense.mean()
nevada_ampop_means = nevada_ampop.mean()

newhamp_expense = df4.loc[df4['STATE'] == 'NEW_HAMPSHIRE','TOTAL_EXPENDITURE']
newhamp_ampop = df4.loc[df4['STATE'] == 'NEW_HAMPSHIRE','GRADES_12_AM']
newhamp_means = newhamp_expense.mean()
newhamp_ampop_means = newhamp_ampop.mean()

newjers_expense = df4.loc[df4['STATE'] == 'NEW_JERSEY','TOTAL_EXPENDITURE']
newjers_ampop = df4.loc[df4['STATE'] == 'NEW_JERSEY','GRADES_12_AM']
newjers_means = newjers_expense.mean()
newjers_ampop_means = newjers_ampop.mean()

newmex_expense = df4.loc[df4['STATE'] == 'NEW_MEXICO','TOTAL_EXPENDITURE']
newmex_ampop = df4.loc[df4['STATE'] == 'NEW_MEXICO','GRADES_12_AM']
newmex_means = newmex_expense.mean()
newmex_ampop_means = newmex_ampop.mean()

newyork_expense = df4.loc[df4['STATE'] == 'NEW_YORK','TOTAL_EXPENDITURE']
newyork_ampop = df4.loc[df4['STATE'] == 'NEW_YORK','GRADES_12_AM']
newyork_means = newyork_expense.mean()
newyork_ampop_means = newyork_ampop.mean()
                          
northcar_expense = df4.loc[df4['STATE'] == 'NORTH_CAROLINA','TOTAL_EXPENDITURE']
northcar_ampop = df4.loc[df4['STATE'] == 'NORTH_CAROLINA','GRADES_12_AM']
northcar_means = northcar_expense.mean()
northcar_ampop_means = northcar_ampop.mean()
                           
northdak_expense = df4.loc[df4['STATE'] == 'NORTH_DAKOTA','TOTAL_EXPENDITURE']
northdak_ampop = df4.loc[df4['STATE'] == 'NORTH_DAKOTA','GRADES_12_AM']
northdak_means = northdak_expense.mean()
northdak_ampop_means = northdak_ampop.mean()

ohio_expense = df4.loc[df4['STATE'] == 'OHIO','TOTAL_EXPENDITURE']
ohio_ampop = df4.loc[df4['STATE'] == 'OHIO','GRADES_12_AM']
ohio_means = ohio_expense.mean()
ohio_ampop_means = ohio_ampop.mean()

okla_expense = df4.loc[df4['STATE'] == 'OKLAHOMA','TOTAL_EXPENDITURE']
okla_ampop = df4.loc[df4['STATE'] == 'OKLAHOMA','GRADES_12_AM']
okla_means = okla_expense.mean()
okla_ampop_means = okla_ampop.mean()

oregon_expense = df4.loc[df4['STATE'] == 'OREGON','TOTAL_EXPENDITURE']
oregon_ampop = df4.loc[df4['STATE'] == 'OREGON','GRADES_12_AM']
oregon_means = oregon_expense.mean()
oregon_ampop_means = oregon_ampop.mean()
                         
penn_expense = df4.loc[df4['STATE'] == 'PENNSYLVANIA','TOTAL_EXPENDITURE']
penn_ampop = df4.loc[df4['STATE'] == 'PENNSYLVANIA','GRADES_12_AM']
penn_means = penn_expense.mean()
penn_ampop_means = penn_ampop.mean()

ri_expense = df4.loc[df4['STATE'] == 'RHODE_ISLAND','TOTAL_EXPENDITURE']
ri_ampop = df4.loc[df4['STATE'] == 'RHODE_ISLAND','GRADES_12_AM']
ri_means = ri_expense.mean()
ri_ampop_means = ri_ampop.mean()

southcar_expense = df4.loc[df4['STATE'] == 'SOUTH_CAROLINA','TOTAL_EXPENDITURE']
southcar_ampop = df4.loc[df4['STATE'] == 'SOUTH_CAROLINA','GRADES_12_AM']
southcar_means = southcar_expense.mean()
southcar_ampop_means = southcar_ampop.mean()

southdak_expense = df4.loc[df4['STATE'] == 'SOUTH_DAKOTA','TOTAL_EXPENDITURE']
southdak_ampop = df4.loc[df4['STATE'] == 'SOUTH_DAKOTA','GRADES_12_AM']
southdak_means = southdak_expense.mean()
southdak_ampop_means = southdak_ampop.mean()

tenn_expense = df4.loc[df4['STATE'] == 'TENNESSEE','TOTAL_EXPENDITURE']
tenn_ampop = df4.loc[df4['STATE'] == 'TENNESSEE','GRADES_12_AM']
tenn_means = tenn_expense.mean()
tenn_ampop_means = tenn_ampop.mean()

##upper bound 
texas_expense = df4.loc[df4['STATE'] == 'TEXAS','TOTAL_EXPENDITURE']
texas_means = texas_expense.mean()
texas_ampop = df4.loc[df4['STATE'] == 'TEXAS','GRADES_12_AM']
texas_ampop_means = texas_ampop.mean()
#print("Mean Texas spent: ",texas_means,"|| Mean 12th grader native american enrollment: ",texas_ampop_means)


utah_expense = df4.loc[df4['STATE'] == 'UTAH','TOTAL_EXPENDITURE']
utah_means = utah_expense.mean()
utah_ampop = df4.loc[df4['STATE'] == 'UTAH','GRADES_12_AM']
utah_ampop_means = utah_ampop.mean()                      

verm_expense = df4.loc[df4['STATE'] == 'VERMONT','TOTAL_EXPENDITURE']
verm_means = verm_expense.mean()
verm_ampop = df4.loc[df4['STATE'] == 'VERMONT','GRADES_12_AM']
verm_ampop_means = verm_ampop.mean()

virg_expense = df4.loc[df4['STATE'] == 'VIRGINIA','TOTAL_EXPENDITURE']
virg_means = virg_expense.mean()
virg_ampop = df4.loc[df4['STATE'] == 'VIRGINIA','GRADES_12_AM']
virg_ampop_means = virg_ampop.mean()

wash_expense = df4.loc[df4['STATE'] == 'WASHINGTON','TOTAL_EXPENDITURE']
wash_means = wash_expense.mean()
wash_ampop = df4.loc[df4['STATE'] == 'WASHINGTON','GRADES_12_AM']
wash_ampop_means = wash_ampop.mean()

wv_expense = df4.loc[df4['STATE'] == 'WEST_VIRGINIA','TOTAL_EXPENDITURE']
wv_means = wv_expense.mean()
wv_ampop = df4.loc[df4['STATE'] == 'WEST_VIRGINIA','GRADES_12_AM']
wv_ampop_means = wv_ampop.mean()

wisc_expense = df4.loc[df4['STATE'] == 'WISCONSIN','TOTAL_EXPENDITURE']
wisc_means = wisc_expense.mean()
wisc_ampop = df4.loc[df4['STATE'] == 'WISCONSIN','GRADES_12_AM']
wisc_ampop_means = wisc_ampop.mean()
#print("Mean Wisconsin spent: ",wisc_means,"|| Mean 12th grader native american enrollment: ",wisc_ampop_means)


wy_expense = df4.loc[df4['STATE'] == 'WYOMING','TOTAL_EXPENDITURE']
wy_means = wy_expense.mean()
wy_ampop = df4.loc[df4['STATE'] == 'WYOMING','GRADES_12_AM']
wy_ampop_means = wy_ampop.mean()

data = {'State':['Alabama',
                 'Alaska',
                 'Arizona',
                 'Arkansas',
                 'California',
                 'Colorado',
                 'Connecticut',
                 'Delaware',
                 'District of Columbia',
                 'Florida',
                 'Georgia',
                 'Hawaii',
                 'Illinois',
                 'Indiana',
                 'Iowa',
                 'Kansas',
                 'Louisana',
                 'Maryland',
                 'Massachusetts',
                 'Michigan',
                 'Minnesota',
                 'Mississippi',
                 'Missouri',
                 'Montanna',
                 'Nebraska',
                 'Nevada',
                 'New Hampshire',
                 'New Mexico',
                 'New York',
                 'North Carolina',
                 'North Dakota',
                 'Ohio',
                 'Oklahoma',
                 'Oregon',
                 'Pennsylvania',
                 'Rhode Island',
                 'South Carolina',
                 'South Dakota',
                 'Tennessee',
                 'Texas',
                 'Utah',
                 'Vermont',
                 'Virginia',
                 'Washington',
                 'West Virgina',
                 'Wisconsin',
                 'Wyoming'],
        'Total_Expenditure_Mean':[alabama_means,
                                  alaska_means,
                                  arizona_means,
                                  arkansas_means,
                                  california_means,
                                  colorado_means,
                                  connecticut_means,
                                  delaware_means,
                                  dcolumbia_means,
                                  florida_means,
                                  georgia_means,
                                  hawaii_means,
                                  illinois_means,
                                  indiana_means,
                                  iowa_means,
                                  kansas_means,
                                  louisana_means,
                                  maryland_means,
                                  massachusetts_means,
                                  michigan_means,
                                  minne_means,
                                  miss_means,
                                  missouri_means,
                                  nebraska_means,
                                  nevada_means,
                                  newhamp_means,
                                  newjers_means,
                                  newmex_means,
                                  newyork_means,
                                  northcar_means,
                                  northdak_means,
                                  ohio_means,
                                  okla_means,
                                  oregon_means,
                                  penn_means,
                                  ri_means,
                                  southcar_means,
                                  southdak_means,
                                  tenn_means,
                                  texas_means,
                                  utah_means,
                                  verm_means,
                                  virg_means,
                                  wash_means,
                                  wv_means,
                                  wisc_means,
                                  wy_means],
        'AM_Grade12_Enrollment':[alabama_ampop_means,
                                  alaska_ampop_means,
                                  arizona_ampop_means,
                                  arkansas_ampop_means,
                                  california_ampop_means,
                                  colorado_ampop_means,
                                  connecticut_ampop_means,
                                  delaware_ampop_means,
                                  dcolumbia_ampop_means,
                                  florida_ampop_means,
                                  georgia_ampop_means,
                                  hawaii_ampop_means,
                                  illinois_ampop_means,
                                  indiana_ampop_means,
                                  iowa_ampop_means,
                                  kansas_ampop_means,
                                  louisana_ampop_means,
                                  maryland_ampop_means,
                                  massachusetts_ampop_means,
                                  michigan_ampop_means,
                                  minne_ampop_means,
                                  miss_ampop_means,
                                  missouri_ampop_means,
                                  nebraska_ampop_means,
                                  nevada_ampop_means,
                                  newhamp_ampop_means,
                                  newjers_ampop_means,
                                  newmex_ampop_means,
                                  newyork_ampop_means,
                                  northcar_ampop_means,
                                  northdak_ampop_means,
                                  ohio_ampop_means,
                                  okla_ampop_means,
                                  oregon_ampop_means,
                                  penn_ampop_means,
                                  ri_ampop_means,
                                  southcar_ampop_means,
                                  southdak_ampop_means,
                                  tenn_ampop_means,
                                  texas_ampop_means,
                                  utah_ampop_means,
                                  verm_ampop_means,
                                  virg_ampop_means,
                                  wash_ampop_means,
                                  wv_ampop_means,
                                  wisc_ampop_means,
                                  wy_ampop_means]}
df = pd.DataFrame(data)
df
# Out:
#                    State  Total_Expenditure_Mean  AM_Grade12_Enrollment
# 0                Alabama            5.734536e+06             470.521739
# 1                 Alaska            1.819398e+06            1888.304348
# 2                Arizona            6.710365e+06            3895.636364
# 3               Arkansas            3.718084e+06             162.521739
# 4             California            5.624945e+07            3445.913043
# 5               Colorado            6.670698e+06             490.826087
# 6            Connecticut            7.191248e+06             121.478261
# 7               Delaware            1.377874e+06              23.521739
# 8   District of Columbia            1.026305e+06             251.500000
# 9                Florida            2.143215e+07             433.565217
# 10               Georgia            1.341764e+07             148.869565
# 11                Hawaii            1.766112e+06              39.782609
# ...

# %%
texas_1993expense = df2.loc[df2['YEAR'] == '1993','TOTAL_EXPENDITURE']
for i in range(len(texas_1993expense)):
    print(texas_1993expense[i])

doof = df2[['STATE','YEAR','TOTAL_EXPENDITURE','GRADES_12_AM','GRADES_12_BL','GRADES_12_HI']]

y1993 = doof.query("YEAR == 1993")['TOTAL_EXPENDITURE'].sum()
y1994 = doof.query("YEAR == 1994")['TOTAL_EXPENDITURE'].sum()
y1995 = doof.query("YEAR == 1995")['TOTAL_EXPENDITURE'].sum()
y1996 = doof.query("YEAR == 1996")['TOTAL_EXPENDITURE'].sum()
y1997 = doof.query("YEAR == 1997")['TOTAL_EXPENDITURE'].sum()
y1998 = doof.query("YEAR == 1998")['TOTAL_EXPENDITURE'].sum()
y1999 = doof.query("YEAR == 1999")['TOTAL_EXPENDITURE'].sum()
y2000 = doof.query("YEAR == 2000")['TOTAL_EXPENDITURE'].sum()
y2001 = doof.query("YEAR == 2001")['TOTAL_EXPENDITURE'].sum()
y2002 = doof.query("YEAR == 2002")['TOTAL_EXPENDITURE'].sum()
y2003 = doof.query("YEAR == 2003")['TOTAL_EXPENDITURE'].sum()
y2004 = doof.query("YEAR == 2004")['TOTAL_EXPENDITURE'].sum()
y2005 = doof.query("YEAR == 2005")['TOTAL_EXPENDITURE'].sum()
y2006 = doof.query("YEAR == 2006")['TOTAL_EXPENDITURE'].sum()
y2007 = doof.query("YEAR == 2007")['TOTAL_EXPENDITURE'].sum()
y2008 = doof.query("YEAR == 2008")['TOTAL_EXPENDITURE'].sum()
y2009 = doof.query("YEAR == 2009")['TOTAL_EXPENDITURE'].sum()
y2010 = doof.query("YEAR == 2010")['TOTAL_EXPENDITURE'].sum()
y2011 = doof.query("YEAR == 2011")['TOTAL_EXPENDITURE'].sum()
y2012 = doof.query("YEAR == 2012")['TOTAL_EXPENDITURE'].sum()
y2013 = doof.query("YEAR == 2013")['TOTAL_EXPENDITURE'].sum()
y2014 = doof.query("YEAR == 2014")['TOTAL_EXPENDITURE'].sum()
y2015 = doof.query("YEAR == 2015")['TOTAL_EXPENDITURE'].sum()
y2016 = doof.query("YEAR == 2016")['TOTAL_EXPENDITURE'].sum()


am1993 = doof.query("YEAR == 1993")['GRADES_12_AM'].sum()
am1994 = doof.query("YEAR == 1994")['GRADES_12_AM'].sum()
am1995 = doof.query("YEAR == 1995")['GRADES_12_AM'].sum()
am1996 = doof.query("YEAR == 1996")['GRADES_12_AM'].sum()
am1997 = doof.query("YEAR == 1997")['GRADES_12_AM'].sum()
am1998 = doof.query("YEAR == 1998")['GRADES_12_AM'].sum()
am1999 = doof.query("YEAR == 1999")['GRADES_12_AM'].sum()
am2000 = doof.query("YEAR == 2000")['GRADES_12_AM'].sum()
am2001 = doof.query("YEAR == 2001")['GRADES_12_AM'].sum()
am2002 = doof.query("YEAR == 2002")['GRADES_12_AM'].sum()
am2003 = doof.query("YEAR == 2003")['GRADES_12_AM'].sum()
am2004 = doof.query("YEAR == 2004")['GRADES_12_AM'].sum()
am2005 = doof.query("YEAR == 2005")['GRADES_12_AM'].sum()
am2006 = doof.query("YEAR == 2006")['GRADES_12_AM'].sum()
am2007 = doof.query("YEAR == 2007")['GRADES_12_AM'].sum()
am2008 = doof.query("YEAR == 2008")['GRADES_12_AM'].sum()
am2009 = doof.query("YEAR == 2009")['GRADES_12_AM'].sum()
am2010 = doof.query("YEAR == 2010")['GRADES_12_AM'].sum()
am2011 = doof.query("YEAR == 2011")['GRADES_12_AM'].sum()
am2012 = doof.query("YEAR == 2012")['GRADES_12_AM'].sum()
am2013 = doof.query("YEAR == 2013")['GRADES_12_AM'].sum()
am2014 = doof.query("YEAR == 2014")['GRADES_12_AM'].sum()
am2015 = doof.query("YEAR == 2015")['GRADES_12_AM'].sum()
am2016 = doof.query("YEAR == 2016")['GRADES_12_AM'].sum()

bl1993 = doof.query("YEAR == 1993")['GRADES_12_BL'].sum()
bl1994 = doof.query("YEAR == 1994")['GRADES_12_BL'].sum()
bl1995 = doof.query("YEAR == 1995")['GRADES_12_BL'].sum()
bl1996 = doof.query("YEAR == 1996")['GRADES_12_BL'].sum()
bl1997 = doof.query("YEAR == 1997")['GRADES_12_BL'].sum()
bl1998 = doof.query("YEAR == 1998")['GRADES_12_BL'].sum()
bl1999 = doof.query("YEAR == 1999")['GRADES_12_BL'].sum()
bl2000 = doof.query("YEAR == 2000")['GRADES_12_BL'].sum()
bl2001 = doof.query("YEAR == 2001")['GRADES_12_BL'].sum()
bl2002 = doof.query("YEAR == 2002")['GRADES_12_BL'].sum()
bl2003 = doof.query("YEAR == 2003")['GRADES_12_BL'].sum()
bl2004 = doof.query("YEAR == 2004")['GRADES_12_BL'].sum()
bl2005 = doof.query("YEAR == 2005")['GRADES_12_BL'].sum()
bl2006 = doof.query("YEAR == 2006")['GRADES_12_BL'].sum()
bl2007 = doof.query("YEAR == 2007")['GRADES_12_BL'].sum()
bl2008 = doof.query("YEAR == 2008")['GRADES_12_BL'].sum()
bl2009 = doof.query("YEAR == 2009")['GRADES_12_BL'].sum()
bl2010 = doof.query("YEAR == 2010")['GRADES_12_BL'].sum()
bl2011 = doof.query("YEAR == 2011")['GRADES_12_BL'].sum()
bl2012 = doof.query("YEAR == 2012")['GRADES_12_BL'].sum()
bl2013 = doof.query("YEAR == 2013")['GRADES_12_BL'].sum()
bl2014 = doof.query("YEAR == 2014")['GRADES_12_BL'].sum()
bl2015 = doof.query("YEAR == 2015")['GRADES_12_BL'].sum()
bl2016 = doof.query("YEAR == 2016")['GRADES_12_BL'].sum()

hi1993 = doof.query("YEAR == 1993")['GRADES_12_HI'].sum()
hi1994 = doof.query("YEAR == 1994")['GRADES_12_HI'].sum()
hi1995 = doof.query("YEAR == 1995")['GRADES_12_HI'].sum()
hi1996 = doof.query("YEAR == 1996")['GRADES_12_HI'].sum()
hi1997 = doof.query("YEAR == 1997")['GRADES_12_HI'].sum()
hi1998 = doof.query("YEAR == 1998")['GRADES_12_HI'].sum()
hi1999 = doof.query("YEAR == 1999")['GRADES_12_HI'].sum()
hi2000 = doof.query("YEAR == 2000")['GRADES_12_HI'].sum()
hi2001 = doof.query("YEAR == 2001")['GRADES_12_HI'].sum()
hi2002 = doof.query("YEAR == 2002")['GRADES_12_HI'].sum()
hi2003 = doof.query("YEAR == 2003")['GRADES_12_HI'].sum()
hi2004 = doof.query("YEAR == 2004")['GRADES_12_HI'].sum()
hi2005 = doof.query("YEAR == 2005")['GRADES_12_HI'].sum()
hi2006 = doof.query("YEAR == 2006")['GRADES_12_HI'].sum()
hi2007 = doof.query("YEAR == 2007")['GRADES_12_HI'].sum()
hi2008 = doof.query("YEAR == 2008")['GRADES_12_HI'].sum()
hi2009 = doof.query("YEAR == 2009")['GRADES_12_HI'].sum()
hi2010 = doof.query("YEAR == 2010")['GRADES_12_HI'].sum()
hi2011 = doof.query("YEAR == 2011")['GRADES_12_HI'].sum()
hi2012 = doof.query("YEAR == 2012")['GRADES_12_HI'].sum()
hi2013 = doof.query("YEAR == 2013")['GRADES_12_HI'].sum()
hi2014 = doof.query("YEAR == 2014")['GRADES_12_HI'].sum()
hi2015 = doof.query("YEAR == 2015")['GRADES_12_HI'].sum()
hi2016 = doof.query("YEAR == 2016")['GRADES_12_HI'].sum()

yearly_ave = {'Year':[1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,
                        2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015],
              'Average Spending':[y1993,y1994,y1995,y1996,y1997,y1998,y1999,y2000,y2001,y2002,y2003,y2004,
                        y2005,y2006,y2007,y2008,y2009,y2010,y2011,y2012,y2013,y2014,y2015],
             'GRADES_12_AM':[am1993,am1994,am1995,am1996,am1997,am1998,am1999,am2000,am2001,am2002,am2003,am2004,
                        am2005,am2006,am2007,am2008,am2009,am2010,am2011,am2012,am2013,am2014,am2015],
             'GRADES_12_BL':[bl1993,bl1994,bl1995,bl1996,bl1997,bl1998,bl1999,bl2000,bl2001,bl2002,bl2003,bl2004,
                        bl2005,bl2006,bl2007,bl2008,bl2009,bl2010,bl2011,bl2012,bl2013,bl2014,bl2015],
             'GRADES_12_HI':[hi1993,bl1994,hi1995,hi1996,hi1997,hi1998,hi1999,hi2000,hi2001,hi2002,hi2003,hi2004,
                        hi2005,hi2006,hi2007,hi2008,hi2009,hi2010,hi2011,hi2012,hi2013,hi2014,hi2015]}

ydf = pd.DataFrame(yearly_ave)
ydf
# Out:
# /Users/katietooher/anaconda3/lib/python3.7/site-packages/pandas/core/ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
#     Year  Average Spending  GRADES_12_AM  GRADES_12_BL  GRADES_12_HI
# 0   1993         244202408       23250.0      318766.0      235666.0
# 1   1994         252664869       24522.0      327543.0      327543.0
# 2   1995         281831835       25038.0      329186.0      248978.0
# 3   1996         297740499       25939.0      341082.0      258546.0
# 4   1997         315861220       26317.0      338470.0      275551.0
# 5   1998         336384794       25114.0      361153.0      281666.0
# 6   1999         360474429       28922.0      367525.0      308823.0
# 7   2000         386177409       29954.0      381190.0      330062.0
# 8   2001         417014891       30869.0      392273.0      351507.0
# ...

# %%
##linear regression, how does total average spending over time affect the enrollment of different demographics of children
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
import statsmodels.api as sm

# %%
#scatter plot 1 just wisconsin
##DONT USE
plt.figure(figsize=(16, 8))
plt.scatter(
    wisc_expense,
    wisc_ampop,
    c='black'
)
plt.xlabel("Money spent on Education($) in Wisconsin Between 1993 - 2016")
plt.ylabel("Enrollment of Native American 12th Graders")
plt.show()

# %% [markdown]
# This shows a fairly linear relationship between amount of money spent over the years and average enrollment of 12th grade Native American children between 1992 and 2016.

# %%
Xw = wisc_expense.values.reshape(-1,1)
yw = wisc_ampop.values.reshape(-1,1)
reg = LinearRegression()
reg.fit(Xw, yw)
print("The linear model is: Y = {:.5} + {:.5}X".format(reg.intercept_[0], reg.coef_[0][0]))
# Out:
# The linear model is: Y = 290.07 + 6.1348e-05X

# %%
predictions = reg.predict(Xw)
plt.figure(figsize=(16, 8))
plt.scatter(
    wisc_expense,
    wisc_ampop,
    c='black'
)
plt.plot(
    wisc_ampop,
    predictions,
    c='blue',
    linewidth=2
)
plt.xlabel("Money spent on Education(m) in Wisconsin 1993 - 2016")
plt.ylabel("Native American Enrollment Averages 1993 - 2016")
plt.show()

# %%
#scatter plot 2 all averages 
#when you put it all together it's quite sporadic -- this is not what i want to know this is the wrong data perspective
##DONT USE
plt.figure(figsize=(16, 8))
plt.scatter(
    data['Total_Expenditure_Mean'],
    data['AM_Grade12_Enrollment'],
    c='black'
)
plt.xlabel("Money spent on Education($) in The Us Per State Between 1993 - 2016")
plt.ylabel("Enrollment of Native American 12th Graders")
plt.show()

# %%
X2 = sm.add_constant(Xw)
est = sm.OLS(yw, X2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.577
# Model:                            OLS   Adj. R-squared:                  0.556
# Method:                 Least Squares   F-statistic:                     28.60
# Date:                Wed, 04 Dec 2019   Prob (F-statistic):           2.65e-05
# Time:                        10:49:50   Log-Likelihood:                -138.16
# No. Observations:                  23   AIC:                             280.3
# Df Residuals:                      21   BIC:                             282.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        290.0743    105.898      2.739      0.012      69.848     510.301
# ...

# %%
##scatter plot 2 all averages 
#when you put it all together it's quite sporadic
plt.figure(figsize=(16, 8))
plt.scatter(
    ydf['Year'],
    ydf['Average Spending'],
    c='black'
)

plt.xlabel("Year")
plt.ylabel("Money spent on Education(m) in The Us Per State Between 1993 - 2016")
plt.show()

# %%
##scatter plot 2 all averages 
#when you put it all together it's quite sporadic
plt.figure(figsize=(16, 8))
plt.scatter(
    ydf['Average Spending'],
    ydf['GRADES_12_AM'],
    c='black'
)
plt.xlabel("Money spent on Education(m) in The Us Per State Between 1993 - 2016")
plt.ylabel("Native American Enrollment Averages 1993 - 2016")
plt.show()

# %%
X = ydf['Average Spending'].values.reshape(-1,1)
y = ydf['GRADES_12_AM'].values.reshape(-1,1)
reg = LinearRegression()
reg.fit(X, y)
print("The linear model is: Y = {:.5} + {:.5}X".format(reg.intercept_[0], reg.coef_[0][0]))
# Out:
# The linear model is: Y = 1.364e+04 + 4.2057e-05X

# %%
predictions = reg.predict(X)
plt.figure(figsize=(16, 8))
plt.scatter(
    ydf['Average Spending'],
    ydf['GRADES_12_AM'],
    c='black'
)
plt.plot(
    ydf['Average Spending'],
    predictions,
    c='blue',
    linewidth=2
)
plt.xlabel("Money spent on Education(m) in The Us Per State Between 1993 - 2016")
plt.ylabel("Native American Enrollment Averages 1993 - 2016")
plt.show()

# %%
X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.876
# Model:                            OLS   Adj. R-squared:                  0.870
# Method:                 Least Squares   F-statistic:                     148.5
# Date:                Wed, 04 Dec 2019   Prob (F-statistic):           5.47e-11
# Time:                        10:50:46   Log-Likelihood:                -209.17
# No. Observations:                  23   AIC:                             422.3
# Df Residuals:                      21   BIC:                             424.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.364e+04   1695.550      8.044      0.000    1.01e+04    1.72e+04
# ...

# %%
sns.regplot(x='Average Spending', y='GRADES_12_AM', data=ydf);
##the data with the confidence interval

# %%
sns.regplot(x='Average Spending', y='GRADES_12_BL', data=ydf);

# %%
Xb = ydf['Average Spending'].values.reshape(-1,1)
yb = ydf['GRADES_12_BL'].values.reshape(-1,1)
reg = LinearRegression()
reg.fit(Xb, yb)
print("The linear model is: Y = {:.5} + {:.5}X".format(reg.intercept_[0], reg.coef_[0][0]))

predictions = reg.predict(Xb)
plt.figure(figsize=(16, 8))
plt.scatter(
    ydf['Average Spending'],
    ydf['GRADES_12_BL'],
    c='black'
)
plt.plot(
    ydf['Average Spending'],
    predictions,
    c='blue',
    linewidth=2
)
plt.xlabel("Money spent on Education(m) in The Us Per State Between 1993 - 2016")
plt.ylabel("African American Enrollment Averages 1993 - 2016")
plt.show()
# Out:
# The linear model is: Y = 1.6911e+05 + 0.00057003X

# %%
X2b = sm.add_constant(Xb)
est = sm.OLS(yb, X2b)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.986
# Model:                            OLS   Adj. R-squared:                  0.985
# Method:                 Least Squares   F-statistic:                     1476.
# Date:                Wed, 04 Dec 2019   Prob (F-statistic):           6.05e-21
# Time:                        11:00:46   Log-Likelihood:                -242.71
# No. Observations:                  23   AIC:                             489.4
# Df Residuals:                      21   BIC:                             491.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.691e+05   7289.902     23.198      0.000    1.54e+05    1.84e+05
# ...

# %%
Xh = ydf['Average Spending'].values.reshape(-1,1)
yh = ydf['GRADES_12_HI'].values.reshape(-1,1)
reg = LinearRegression()
reg.fit(Xh, yh)
print("The linear model is: Y = {:.5} + {:.5}X".format(reg.intercept_[0], reg.coef_[0][0]))

predictions = reg.predict(Xb)
plt.figure(figsize=(16, 8))
plt.scatter(
    ydf['Average Spending'],
    ydf['GRADES_12_HI'],
    c='black'
)
plt.plot(
    ydf['Average Spending'],
    predictions,
    c='blue',
    linewidth=2
)
plt.xlabel("Money spent on Education(m) in The Us Per State Between 1993 - 2016")
plt.ylabel("Hispanic American Enrollment Averages 1993 - 2016")
plt.show()
# Out:
# The linear model is: Y = -1.419e+05 + 0.0013265X

# %%
X2h = sm.add_constant(Xh)
est = sm.OLS(yh, X2h)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.876
# Model:                            OLS   Adj. R-squared:                  0.870
# Method:                 Least Squares   F-statistic:                     148.8
# Date:                Wed, 04 Dec 2019   Prob (F-statistic):           5.36e-11
# Time:                        11:02:14   Log-Likelihood:                -288.53
# No. Observations:                  23   AIC:                             581.1
# Df Residuals:                      21   BIC:                             583.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1.419e+05   5.34e+04     -2.656      0.015   -2.53e+05   -3.08e+04
# ...

# %%
sns.regplot(x='Average Spending', y='GRADES_12_HI', data=ydf);

# %%
X = np.column_stack((ydf['GRADES_12_AM'], ydf['GRADES_12_BL'], ydf['GRADES_12_HI']))
y = ydf['Average Spending']
X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:       Average Spending   R-squared:                       0.986
# Model:                            OLS   Adj. R-squared:                  0.984
# Method:                 Least Squares   F-statistic:                     452.1
# Date:                Wed, 04 Dec 2019   Prob (F-statistic):           7.73e-18
# Time:                        11:12:59   Log-Likelihood:                -414.18
# No. Observations:                  23   AIC:                             836.4
# Df Residuals:                      19   BIC:                             840.9
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -2.639e+08   5.81e+07     -4.544      0.000   -3.85e+08   -1.42e+08
# ...

# %%
##modeling test scores over time with average total spending per these three states 
#df2 is the cleaned dataset

df5 = df2[['YEAR','STATE','TOTAL_EXPENDITURE','AVG_MATH_8_SCORE',
            'AVG_READING_8_SCORE']].copy()
df5 = df5.dropna(subset=['AVG_MATH_8_SCORE'])
##upper bound
#california_expense = df4.loc[df4['STATE'] == 'CALIFORNIA','TOTAL_EXPENDITURE']
california_scores = df5.loc[df5['STATE'] == 'CALIFORNIA','AVG_MATH_8_SCORE']
california_means = california_expense.mean()
#california_ampop_means = california_ampop.mean()

##middle range spending
#wisc_expense = df4.loc[df4['STATE'] == 'WISCONSIN','TOTAL_EXPENDITURE']
#wisc_means = wisc_expense.mean()
wisc_sc = df5.loc[df5['STATE'] == 'WISCONSIN','AVG_MATH_8_SCORE']
#wisc_ampop_means = wisc_ampop.mean()

##lowest spending
#southdak_expense = df4.loc[df4['STATE'] == 'SOUTH_DAKOTA','TOTAL_EXPENDITURE']
southdak_sc = df5.loc[df5['STATE'] == 'SOUTH_DAKOTA','AVG_MATH_8_SCORE']
#southdak_means = southdak_expense.mean()
#southdak_ampop_means = southdak_ampop.mean()

#df_filtered = df.query('STATE == SOUTH_DAKOTA & YEAR == 1992')
#subsetDataFrame = df5[df5['STATE'] == 'SOUTH_DAKOTA' & df5['YEAR'] == 1992,'AVG_MATH_8_SCORE']
cal96 = df5.loc[(df5['STATE'] == 'CALIFORNIA') & (df5['YEAR'] == 1996), 'AVG_MATH_8_SCORE']      
cal00 = df5.loc[(df5['STATE'] == 'CALIFORNIA') & (df5['YEAR'] == 2000), 'AVG_MATH_8_SCORE'] 
cal3 = df5.loc[(df5['STATE'] == 'CALIFORNIA') & (df5['YEAR'] == 2003), 'AVG_MATH_8_SCORE'] 
cal5 = df5.loc[(df5['STATE'] == 'CALIFORNIA') & (df5['YEAR'] == 2005), 'AVG_MATH_8_SCORE'] 
cal7 = df5.loc[(df5['STATE'] == 'CALIFORNIA') & (df5['YEAR'] == 2007), 'AVG_MATH_8_SCORE'] 
cal9 = df5.loc[(df5['STATE'] == 'CALIFORNIA') & (df5['YEAR'] == 2009), 'AVG_MATH_8_SCORE'] 
cal11 = df5.loc[(df5['STATE'] == 'CALIFORNIA') & (df5['YEAR'] == 2011), 'AVG_MATH_8_SCORE'] 
cal13 = df5.loc[(df5['STATE'] == 'CALIFORNIA') & (df5['YEAR'] == 2013), 'AVG_MATH_8_SCORE'] 
cal16 = df5.loc[(df5['STATE'] == 'CALIFORNIA') & (df5['YEAR'] == 2016), 'AVG_MATH_8_SCORE'] 

wisc96 = df5.loc[(df5['STATE'] == 'WISCONSIN') & (df5['YEAR'] == 1996), 'AVG_MATH_8_SCORE']      
wisc00 = df5.loc[(df5['STATE'] == 'WISCONSIN') & (df5['YEAR'] == 2000), 'AVG_MATH_8_SCORE'] 
wisc3 = df5.loc[(df5['STATE'] == 'WISCONSIN') & (df5['YEAR'] == 2003), 'AVG_MATH_8_SCORE'] 
wisc5 = df5.loc[(df5['STATE'] == 'WISCONSIN') & (df5['YEAR'] == 2005), 'AVG_MATH_8_SCORE'] 
wisc7 = df5.loc[(df5['STATE'] == 'WISCONSIN') & (df5['YEAR'] == 2007), 'AVG_MATH_8_SCORE'] 
wisc9 = df5.loc[(df5['STATE'] == 'WISCONSIN') & (df5['YEAR'] == 2009), 'AVG_MATH_8_SCORE'] 
wisc11 = df5.loc[(df5['STATE'] == 'WISCONSIN') & (df5['YEAR'] == 2011), 'AVG_MATH_8_SCORE'] 
wisc13 = df5.loc[(df5['STATE'] == 'WISCONSIN') & (df5['YEAR'] == 2013), 'AVG_MATH_8_SCORE'] 
wisc16 = df5.loc[(df5['STATE'] == 'WISCONSIN') & (df5['YEAR'] == 2016), 'AVG_MATH_8_SCORE'] 

#scoresdata = {'Year':[1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,
#                        2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015],'State':['California','Wisconsin','South Dakota'],'Average Math 8 Score':[california_scores,wisc_sc,southdak_sc]}

#dfscores = pd.DataFrame(scoresdata)
#dfscores
# Out:
# 202    282.848742
# Name: AVG_MATH_8_SCORE, dtype: float64
