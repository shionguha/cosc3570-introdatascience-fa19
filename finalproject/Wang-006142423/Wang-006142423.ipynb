# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import scipy as scipy
import statsmodels.api as sm
get_ipython().run_line_magic('matplotlib', 'inline')

# %% [markdown]
# ,names=['No','Year', 'Month', 'Day', 'Hour', 'Season', 'PM_Caotangsi', 'PM_Shahepu', 'PM_US Post', 'DEWP', 'HUMI','PRES','Temp','cbwd','lws','percipitation','Iprec']

# %%
# bring in data
sns.set(style = "ticks")
chengdu = pd.read_csv('Wang-006142423.csv')
chengdu.head(10)
# Out:
#    No  year  month  day  hour  season  PM_Caotangsi  PM_Shahepu  PM_US Post  \
# 0   1  2010      1    1     0       4           NaN         NaN         NaN
# 1   2  2010      1    1     1       4           NaN         NaN         NaN
# 2   3  2010      1    1     2       4           NaN         NaN         NaN
# 3   4  2010      1    1     3       4           NaN         NaN         NaN
# 4   5  2010      1    1     4       4           NaN         NaN         NaN
# 5   6  2010      1    1     5       4           NaN         NaN         NaN
# 6   7  2010      1    1     6       4           NaN         NaN         NaN
# 7   8  2010      1    1     7       4           NaN         NaN         NaN
# 8   9  2010      1    1     8       4           NaN         NaN         NaN
# 9  10  2010      1    1     9       4           NaN         NaN         NaN
#
#    DEWP   HUMI    PRES  TEMP cbwd  Iws  precipitation  Iprec
# 0   4.0  81.20  1022.0   7.0   cv  1.0            0.0    0.0
# ...

# %%
g = sns.FacetGrid(chengdu, col = "season", hue = "year")
g.map(plt.scatter, "day", "PM_Caotangsi", alpha = 0.7)
g.add_legend();

g = sns.FacetGrid(chengdu, col = "season", hue = "year")
g.map(plt.scatter, "day", "PM_Shahepu", alpha = 0.7)
g.add_legend();

g = sns.FacetGrid(chengdu, col = "season", hue = "year")
g.map(plt.scatter, "day", "PM_US Post", alpha = 0.7)
g.add_legend();

# %%
g =sns.FacetGrid(chengdu, col = "year", aspect = 0.8)
g.map(sns.barplot, "season", "HUMI")
g =sns.FacetGrid(chengdu, col = "year", aspect = 0.8)
g.map(sns.barplot, "season", "DEWP")
g =sns.FacetGrid(chengdu, col = "year", aspect = 0.8)
g.map(sns.barplot, "season", "TEMP")
g =sns.FacetGrid(chengdu, col = "year", aspect = 0.8)
g.map(sns.barplot, "season", "PRES")
# Out:
# /Users/cheng/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:715: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
g = sns.FacetGrid(chengdu, col="year")
g.map(plt.hist, "PM_Caotangsi");
g = sns.FacetGrid(chengdu, col="year")
g.map(plt.hist, "PM_Shahepu");
g = sns.FacetGrid(chengdu, col="year")
g.map(plt.hist, "PM_US Post");

# %%
sns.barplot(x = "year", y = "PM_Caotangsi" , data = chengdu)
plt.ylabel("PM_Caotangsi")
plt.title("2010-2015 PM_Caotangsit")
plt.show()

sns.barplot(x = "year", y = "PM_Shahepu" , data = chengdu)
plt.ylabel("PM_Shahepu")
plt.title("2010-2015 PM_Shahepu")
plt.show()

sns.barplot(x = "year", y = "PM_US Post" , data = chengdu)
plt.ylabel("PM_US Post")
plt.title("2010-2015 PM_US Post")
plt.show()

# %%
facet = sns.FacetGrid(chengdu, hue="year",aspect=3)
facet.map(sns.kdeplot,'PM_US Post',shade= False)
facet.set(xlim=(0, chengdu['PM_US Post'].max()))
facet.add_legend()

facet = sns.FacetGrid(chengdu, hue="year",aspect=3)
facet.map(sns.kdeplot,'PM_Caotangsi',shade= False)
facet.set(xlim=(0, chengdu['PM_Caotangsi'].max()))
facet.add_legend()

facet = sns.FacetGrid(chengdu, hue="year",aspect=3)
facet.map(sns.kdeplot,'PM_Shahepu',shade= False)
facet.set(xlim=(0, chengdu['PM_Shahepu'].max()))
facet.add_legend()

# %%
grid = sns.FacetGrid(chengdu, row='month', size=4, aspect=3)
grid.map(sns.pointplot, 'day', 'PM_US Post', 'season', palette='deep')
grid.add_legend()

# %%
grid = sns.FacetGrid(chengdu, row='month', size=4, aspect=3)
grid.map(sns.pointplot, 'day', 'PM_Caotangsi', 'season', palette='deep')
grid.add_legend()

# %%
grid = sns.FacetGrid(chengdu, row='month', size=4, aspect=3)
grid.map(sns.pointplot, 'day', 'PM_Shahepu', 'season', palette='deep')
grid.add_legend()

# %%
facet = sns.FacetGrid(chengdu, hue="season",aspect=3)
facet.map(sns.kdeplot,'PM_Caotangsi',shade= False)
facet.set(xlim=(0, chengdu['day'].max()))
facet.add_legend()

facet = sns.FacetGrid(chengdu, hue="season",aspect=3)
facet.map(sns.kdeplot,'PM_Shahepu',shade= False)
facet.set(xlim=(0, chengdu['day'].max()))
facet.add_legend()

facet = sns.FacetGrid(chengdu, hue="season",aspect=3)
facet.map(sns.kdeplot,'PM_US Post',shade= False)
facet.set(xlim=(0, chengdu['day'].max()))
facet.add_legend()

# %%
sns.barplot(x = "year", y = "PM_Caotangsi" , data = chengdu)
plt.ylabel("PM_Caotangsi")
plt.title("2010-2015 PM_Caotangsit")
plt.show()

sns.barplot(x = "year", y = "PM_Shahepu" , data = chengdu)
plt.ylabel("PM_Shahepu")
plt.title("2010-2015 PM_Shahepu")
plt.show()

sns.barplot(x = "year", y = "PM_US Post" , data = chengdu)
plt.ylabel("PM_US Post")
plt.title("2010-2015 PM_US Post")
plt.show()
